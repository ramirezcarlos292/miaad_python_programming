# %% [markdown]
# <a href="https://colab.research.google.com/github/ramirezcarlos292/MIAAD/blob/main/Python_Programming_MIA-0006-24/2_Manejo_de_archivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Laboratorio 1**
#
# # Objetivo del Laboratorio 1.
# Que los estudiantes comprenden y aplicaquen los conceptos fundamentales para el manejo de archivos en Python, específicamente para leer y procesar archivos de texto (.txt), utilizando las funciones básicas de apertura, lectura y cierre de archivos. Al finalizar la actividad, los estudiantes podrán:
#
#
# *   Abrir un archivo de texto, almacenado en Google Drive, utilizando Python.
# *   Leer el contenido de un archivo línea por línea o de forma completa.
# *   Aplicar técnicas para manejar archivos de manera eficiente, incluyendo la gestión de excepciones.
# *   Cerrar correctamente un archivo después de su uso para evitar pérdidas de datos o errores.

# %% [markdown]
# # Inicio del Laboratorio
#
#
# ---
# Para abrir o escribir en un archivo, primero es necesario abrirlo. Este proceso implica interactuar con el sistema operativo, que es responsable de localizar y gestionar los datos asociados a cada archivo. Al abrir un archivo, le indicas al sistema operativo que busque un archivo específico por su nombre y confirme que realmente existe.
#
# **Antes de iniciar con el Laboratorio 1**
#
# Para trabajar las actividades de este laboratorio, es importante que se inicie el entorno de ejecución. Para verificar si el entorno se ha conectado lo puedes verificar en la esquina superior derecha a un lado de Gemini. Si el entorno se está ejecutando debe aparecer las palabras RAM y Disco.
#
# ![Entorno.png](data:image/png;base64,...)
#
#
#
# Si el entorno no está en ejecución, entonces aparecerá la siguiente figura:
#
#
# ![sinentorno.png](data:image/png;base64,...)
#
# Para poner en ejecución el entorno es necesario hacer click en conectar/connect. Si todo está bien, entonces aparecerán las palabras RAM y Disco y el símbolo de "palomita" en color verde.
#
# ![Screen Shot 2025-01-24 at 0.18.02.png](data:image/png;base64,...)
#
#
#
# En este laboratorio 1, trabajaremos con los archivos de texto `mbox.txt` y `mbox-short.txt`, los cuales deberás descargar desde el campus virtual (CV) y subir al Google Drive, el cual deberá estar conectado previamente. Para ello, sigue los pasos vistos en el video.
#
# También se puede hacer mediante código, tal y como se pone a continuación. Ejecutar el código para montar el Drive

# %%
#Esta parte del código monta tu Google Drive en el entorno Colab
#Al ejecutar drive.mount(), te pedirá que autorices a Google Colab para
#Acceder a tu Google Drive
from google.colab import drive

#Después de la autorización, tu Google Drive estará Disponible en el Sistema
#de archivos de Colab en la ruta /content/drive/
#Si todo ha salido bien deberá aparecer un mensaje de
#Mounted at /content/drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Una vez conectado el Google Drive, almacena los dos archivos de texto que descargaste de CV una carpeta de Google Drive llamada **ClassFiles**. Asegúrate de colocarla en **MyDrive**. En la imagen adjunta podrás ver cómo localizar el archivo.
#
# ![download.jpeg](data:image/jpeg;base64,...)

# %%
import os
print(os.getcwd())

# !wget -P /content/drive/MyDrive/ClassFiles/ https://github.com/csev/py4e/raw/refs/heads/master/code3/mbox-short.txt
# !wget -P /content/drive/MyDrive/ClassFiles/ https://raw.githubusercontent.com/csev/py4e/refs/heads/master/code3/mbox.txt
# Out:
# /content
# --2025-08-11 02:36:10--  https://github.com/csev/py4e/raw/refs/heads/master/code3/mbox-short.txt
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/csev/py4e/refs/heads/master/code3/mbox-short.txt [following]
# --2025-08-11 02:36:10--  https://raw.githubusercontent.com/csev/py4e/refs/heads/master/code3/mbox-short.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94626 (92K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/ClassFiles/mbox-short.txt.9’
#
# mbox-short.txt.9    100%[===================>]  92.41K  --.-KB/s    in 0.02s
#
# ...

# %% [markdown]
# # Manejo inicial de un archivo
#
# Una vez cargado los archivos en la carpeta ClassFiles en tu Google Drive, nos vamos asegurar que se pueden abrir. Para ello, usaremos la función `open( )` que abre al archivo `mbox.txt` en modo lectura. Recuerda ejecutar el código.

# %%
#Función open() para abrir el archivo de texto en modo lectura
archivo = open('/content/drive/MyDrive/ClassFiles/mbox.txt')

#El objeto del archivo se encuentra en la variable "archivo"
#Se imprime el objeto de tipo archivo que representa mbox.txt.
#Esto no mostrará el contenido del archivo.
print(archivo)
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/ClassFiles/mbox.txt' mode='r' encoding='utf-8'>

# %% [markdown]
# *   Si la operación de open el archivo es exitosa, el sistema operativo nos proporciona un manejador de archivo. Este manejador no contiene los datos del archivo, sino que actúa como un "manejador" (handler) que nos permite acceder a los datos. Recibirás un manejador de archivo solo si el archivo solicitado existe y si tienes los permisos necesarios para leerlo.
#
# > <_io.TextIOWrapper name='/content/drive/MyDrive/ClassFiles/mbox.txt' mode='r' encoding='UTF-8'>
#
#
#
# *  En caso contrario, si el archivo o la localizacion del archivo no se encuentran, PYTHON  enviarará un **traceback** como el siguiente:
#
# >FileNotFoundError  Traceback (most recent call last)
# <ipython-input-4-0c48139f2450> in <cell line: 0>()
# ----> 1 archivo = open('/content/drive/MyDrive/ClassFiles/mbox.txt')
#       2 print(archivo)
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ClassFiles/mbox.txt'

# %% [markdown]
# ----------------------

# %% [markdown]
# Aunque la variable archivo no contiene los datos de un documento, es bastante fácil utilizarlo en un bucle for para leer a través del archivo y contar cada una de sus líneas.
#
# Para ello, ejecuta la siguiente linea de codigo.
#
# **IMPORTANTE, PARA QUE LAS LINEAS DE CODIGO PUEDAN FUNCIONAR, LA PRIMER CELDA DEBE ESTAR ACTIVA (LA DEBES DE EJECUTAR), DE LO CONTRARIO TENDRAS UN TRACEBACK**

# %%
contador = 0
for linea in archivo:
  contador = contador + 1
print('Contador de líneas:', contador)
# Out:
# Contador de líneas: 132045

# %% [markdown]
# Como podrás observar, el ciclo FOR nos muestra cuantas líneas de texto contiene nuestro archivo de ejemplo.
#
# Podemos utilizar la variable de archivos como una secuencia dentro de un bucle for. Este bucle simplemente cuenta el número de líneas en el archivo e imprime cada una de ellas. Una traducción aproximada de este bucle en español sería: "para cada línea en el archivo representado por el manejador de archivo, suma uno a la variable count."
#
# La razón por la cual la función open no lee el archivo completo de inmediato es que el archivo puede ser muy grande, incluso con varios gigabytes de datos. La función open tarda el mismo tiempo sin importar el tamaño del archivo. En realidad, es el bucle for el que provoca que los datos sean leídos desde el archivo.
#
# Cuando se lee el archivo de esta manera con un bucle for, Python se encarga de dividir los datos en líneas utilizando el separador de líneas. Python lee cada línea hasta encontrar el separador, e incluye este separador como el último carácter en la variable line durante cada iteración del bucle for.
#
# Debido a que el bucle for lee los datos línea por línea, puede procesar y contar las líneas de archivos muy grandes de manera eficiente, sin agotar la memoria RAM. El programa anterior es capaz de contar las líneas de archivos de cualquier tamaño utilizando muy poca memoria, ya que cada línea se lee, cuenta y luego se descarta.
#
# -------------

# %% [markdown]
# > Si sabes que el archivo es relativamente pequeño comparado al tamaño de tu memoria principal, puedes leer el archivo completo en una sola cadena utilizando el método **read** en el manejador de archivos.
#
# Para ello, vamos a emplear un archivo mas corto que se llama mbox-short. Por lo que ejecuta la siguiente linea de codigo

# %%
archivo1 = open('/content/drive/MyDrive/ClassFiles/mbox-short.txt')
print(f"Length of mbox-short: {len(archivo1.read())}")
print(f"Length of mbox: {len(archivo.read())}")
# Out:
# Length of mbox-short: 94626
# Length of mbox: 0

# %% [markdown]
# > Como ejercicio adicional, intenta realizarlo con el archivo `mbox.txt` y verifica si esto te da un resultado.
# ************

# %% [markdown]
# # Lectura de un archivo en Python
# Para leer un archivo completo en Python, puedes usar varias formas, dependiendo de cómo quieras procesar el contenido. A continuación te muestro cómo hacerlo de las maneras más comunes:

# %% [markdown]
# **Este método lee todo el contenido del archivo y lo guarda como una cadena de texto:**

# %%
# Abre el archivo en modo lectura ('r')
with open('/content/drive/MyDrive/ClassFiles/mbox-short.txt', 'r') as archivo:
    # Lee todo el contenido del archivo
    contenido = archivo.read()

# Imprime el contenido del archivo
print(contenido)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# **Si prefieres leer el archivo línea por línea, puedes usar un bucle para iterar sobre las líneas del archivo:**

# %%
with open('/content/drive/MyDrive/ClassFiles/mbox-short.txt', 'r') as archivo:
    # Itera sobre cada línea del archivo
    for linea in archivo:
        # Imprime cada línea
        print(linea, end='')  # end='' evita un salto de línea extra
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# **Si deseas almacenar todas las líneas en una lista, puedes hacerlo de la siguiente manera:**

# %%
# Abre el archivo en modo lectura ('r')
with open('/content/drive/MyDrive/ClassFiles/mbox-short.txt', 'r') as archivo:
    # Lee todas las líneas y las guarda en una lista
    lineas = archivo.readlines()
# Imprime todas las líneas
print(lineas)
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n', 'Return-Path: <postmaster@collab.sakaiproject.org>\n', 'Received: from murder (mail.umich.edu [141.211.14.90])\n', '\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n', '\t Sat, 05 Jan 2008 09:14:16 -0500\n', 'X-Sieve: CMU Sieve 2.3\n', 'Received: from murder ([unix socket])\n', '\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n', '\t Sat, 05 Jan 2008 09:14:16 -0500\n', 'Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n', '\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n', '\tSat, 5 Jan 2008 09:14:15 -0500\n', 'Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n', '\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n', '\t 5 Jan 2008 09:14:10 -0500\n', 'Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n', '\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n', '\tSat,  5 Jan 2008 14:10:05 +0000 (GMT)\n', 'Message-ID: <
# ...

# %% [markdown]
# #Búsqueda a través de un archivo
#
# Cuando buscas a través de los datos de un archivo, un patrón muy común es leer el archivo, ignorar la mayoría de las líneas y solamente procesar líneas que cumplan con una condición particular. Podemos combinar el patrón de leer un archivo con métodos de cadenas para construir mecanismos de búsqueda sencillos.
#
#
# Por ejemplo, si queremos leer un archivo y solamente imprimir las líneas que comienzan con el prefijo “From:”, podríamos usar el método de cadenas startswith para seleccionar solo aquellas líneas con el prefijo deseado:

# %%
archivo = open('/content/drive/MyDrive/ClassFiles/mbox.txt')
contador = 0
for linea in archivo:
  if linea.startswith('From:'):
    print(linea)
# Out:
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: zqian@umich.edu
#
# From: rjlowe@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: gsilver@umich.edu
#
# From: gsilver@umich.edu
#
# From: zqian@umich.edu
#
# From: gsilver@umich.edu
#
# From: wagnermr@iupui.edu
#
# From: zqian@umich.edu
#
# From: antranig@caret.cam.ac.uk
#
# From: gopal.ramasammycook@gmail.com
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: david.horwitz@uct.ac.za
#
# From: stephen.marquard@uct.ac.za
#
# From: louis@media.berkeley.edu
#
# From: louis@media.berkeley.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: cwen@iupui.edu
#
# From: ray@media.berkeley.edu
#
# From: cwen@iupui.edu
#
# From: zqian@umich.edu
#
# From: cwen@iupui.edu
#
# From: zqian@umich.edu
#
# From: zqian@umich.edu
#
# ...

# %% [markdown]
# La salida parece correcta porque las líneas que estamos buscando son aquellas que comienzan con "From:", pero ¿por qué vemos líneas vacías adicionales? Esto ocurre debido al carácter invisible de salto de línea. Cada línea leída termina con un salto de línea, por lo que cuando usamos la sentencia print para imprimir el contenido de la variable `line`, esta incluye el salto de línea al final, y luego el comando print agrega otro salto de línea, lo que provoca el efecto de doble salto de línea que observamos.
#
# Podemos usar el troceado de líneas para imprimir todos los caracteres excepto el último, pero una forma más sencilla de hacerlo es utilizar el método rstrip, que elimina los espacios en blanco al final de una cadena, como por ejemplo:

# %%
archivo = open('/content/drive/MyDrive/ClassFiles/mbox.txt')
for linea in archivo:
    linea = linea.rstrip()
    if linea.startswith('From:'):
        print(linea)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# ...

# %% [markdown]
# A medida que tus programas para procesar archivos se vuelvan más complejos, puede que desees organizar tus bucles de búsqueda utilizando la instrucción continue. El concepto principal de un bucle de búsqueda es que estás buscando líneas "relevantes" e ignorando las "irrelevantes". Y cuando encuentras una línea relevante, realizas alguna acción con ella.
#
# Podemos estructurar el bucle siguiendo el patrón de ignorar las líneas irrelevantes de la siguiente manera:

# %%
archivo = open('/content/drive/MyDrive/ClassFiles/mbox.txt')
for linea in archivo:
    linea = linea.rstrip()
    # Ignorar 'líneas que no nos interesan'
    if not linea.startswith('From:'):
        continue
    # Procesar la línea que nos 'interesa'
    print(linea)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: cwen@iupui.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: zqian@umich.edu
# From: mmmay@indiana.edu
# From: cwen@iupui.edu
# ...

# %% [markdown]
# El resultado del programa es el mismo. En este caso, las líneas irrelevantes son aquellas que no comienzan con "From:", por lo que las ignoramos utilizando continue. Por otro lado, las líneas "relevantes" (las que comienzan con "From:") las procesamos.
#
# Podemos usar el método find de las cadenas para simular la función de búsqueda de un editor de texto, que localiza las líneas donde aparece una cadena en cualquier parte. Dado que find busca cualquier ocurrencia de una cadena dentro de otra y devuelve la posición de esa cadena o -1 si no se encuentra, podemos escribir el siguiente bucle para mostrar las líneas que contienen la cadena "@uct.ac.za" (es decir, las provenientes de la Universidad de Cape Town en Sudáfrica):

# %%
archivo = open('/content/drive/MyDrive/ClassFiles/mbox.txt')
for linea in archivo:
    linea = linea.rstrip()
    if linea.find('@uct.ac.za') == -1: continue
    print(linea)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to stephen.marquard@uct.ac.za using -f
# From: stephen.marquard@uct.ac.za
# Author: stephen.marquard@uct.ac.za
# From david.horwitz@uct.ac.za Fri Jan  4 07:02:32 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# r39753 | david.horwitz@uct.ac.za | 2008-01-04 13:05:51 +0200 (Fri, 04 Jan 2008) | 1 line
# From david.horwitz@uct.ac.za Fri Jan  4 06:08:27 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# Author: david.horwitz@uct.ac.za
# From david.horwitz@uct.ac.za Fri Jan  4 04:49:08 2008
# X-Authentication-Warning: nakamura.uits.iupui.edu: apache set sender to david.horwitz@uct.ac.za using -f
# From: david.horwitz@uct.ac.za
# ...

# %% [markdown]
# # Cerrar un archivo de forma correcta
#
# En Python, es importante cerrar los archivos después de usarlos para evitar pérdidas de datos o errores, especialmente si el archivo ha sido abierto en modo de escritura o se han realizado cambios. Hay dos formas principales de hacerlo:
# ************
# El uso de with es la manera más sencilla y segura de manejar archivos en Python, ya que se encarga automáticamente de cerrar el archivo una vez que el bloque de código se completa, incluso si ocurre un error dentro del bloque.
#
# ```
# # Abrir el archivo con 'with', lo que asegura que se cierre automáticamente
# with open('archivo.txt', 'r') as archivo:
#     # Leer el contenido o procesar el archivo
#     contenido = archivo.read()
#     print(contenido)
#
# # No es necesario llamar a archivo.close(), ya que 'with' lo hace automáticamente.
# ```
# ***********
# Usando open() y close() manualmente
# Si no usas with, debes asegurarte de cerrar el archivo de forma explícita después de haber terminado de trabajar con él. Esto se hace con el método close().
#
#
#
# ```
# # Abrir el archivo manualmente
# archivo = open('archivo.txt', 'r')
#
# # Leer el contenido o procesar el archivo
# contenido = archivo.read()
# print(contenido)
#
# # Cerrar el archivo manualmente
# archivo.close()
# ```

# %% [markdown]
# # Practica 1: Manejo de Archivos
# En esta practica, se te pide que diseñes un código en Google Colab para analizar el archivo mbox.txt (revisa el laboratorio 1). El código deberá extraer las mediciones contenidas en cada línea que contiene la cadena X-DSPAM-Confidence.
#
# Objetivos:
#
# 1. Tu código debe extraer únicamente los datos numéricos de las líneas que contienen la cadena X-DSPAM-Confidence en el archivo mbox.txt.
#
# 2. Para extraer los datos númericos usa las intrucciones vistas en el laboratorio 1 (startswith). Aquí no se usan expresiones regulares.
# 3. Los datos numéricos los deberás guardar en una lista y posteriormente mostrar los resultados de cada medición encontrada.
# 4. Explica brevemente en tu Google Colab qué realiza el código.
# 5. Calcular y mostrar en pantalla:
#   * La cantidad de datos extraídos.
#   * La sumatoria de los datos.
#   * El promedio de los datos.
#   * La varianza de los datos.

# %%
# Saber si el archivo esta en el path correcto
# print(os.path.exists('/content/drive/MyDrive/ClassFiles/mbox-short.txt'))
with open('/content/drive/MyDrive/ClassFiles/mbox.txt', 'r') as archivo:
  valores = []
  for linea in archivo:
    linea = linea.rstrip()
    if not linea.startswith('X-DSPAM-Confidence'):
      continue
    valores.append(float(linea[20:]))

# Lista de valores extraidos
print(f"Valores de X_DSPAM-Confidence: \n {valores}")

# Cantidad de datos extraidos
cantidad_de_datos = len(valores)
print(f"Cantidad de valores extraidos: \n {cantidad_de_datos}")

# Sumatoria de los datos
sumatoria = 0
for valor in valores:
  sumatoria += valor
print(f"Sumatoria: {sumatoria}")

# promedio de los datos
promedio = sumatoria/cantidad_de_datos
print(f"Promedio: {promedio}")

accum = 0
for valor in valores:
  accum += (valor - promedio)**2
var = accum / cantidad_de_datos
print(f"Varianza: {var}")
# Out:
# Valores de X_DSPAM-Confidence:
# ...

# %%
# Comprobacion usando numpy
import numpy as np

# convertir lista de valores a numpy
valores = np.array(valores)

# Calcular sumatoria
print(f"Sumatoria: {valores.sum()}")

# Calcular promedio
print(f"Promedio: {valores.mean()}")

# Calcular la varianza
print(f"Varianza: {valores.var()}")
# Out:
# Sumatoria: 1606.7481
# Promedio: 0.8941280467445744
# Varianza: 0.012322985913435768
